# %%
from sklearn import datasets
import pandas as pd
import numpy as np

iris = datasets.load_iris()
x = pd.DataFrame(iris.data)
y = pd.DataFrame(iris.target)
x
y
#target_names = iris.target_names

#df = pd.DataFrame(columns=['width', 'length', 'petal width', 'petal length','type'])

df = pd.concat([x,y], axis = 1)
df
print(df.values)
#print(df[df[0]==1])
# Out:
# [[ 5.1  3.5  1.4  0.2  0. ]
#  [ 4.9  3.   1.4  0.2  0. ]
#  [ 4.7  3.2  1.3  0.2  0. ]
#  [ 4.6  3.1  1.5  0.2  0. ]
#  [ 5.   3.6  1.4  0.2  0. ]
#  [ 5.4  3.9  1.7  0.4  0. ]
#  [ 4.6  3.4  1.4  0.3  0. ]
#  [ 5.   3.4  1.5  0.2  0. ]
#  [ 4.4  2.9  1.4  0.2  0. ]
#  [ 4.9  3.1  1.5  0.1  0. ]
#  [ 5.4  3.7  1.5  0.2  0. ]
#  [ 4.8  3.4  1.6  0.2  0. ]
#  [ 4.8  3.   1.4  0.1  0. ]
#  [ 4.3  3.   1.1  0.1  0. ]
#  [ 5.8  4.   1.2  0.2  0. ]
#  [ 5.7  4.4  1.5  0.4  0. ]
#  [ 5.4  3.9  1.3  0.4  0. ]
#  [ 5.1  3.5  1.4  0.3  0. ]
#  [ 5.7  3.8  1.7  0.3  0. ]
#  [ 5.1  3.8  1.5  0.3  0. ]
#  [ 5.4  3.4  1.7  0.2  0. ]
#  [ 5.1  3.7  1.5  0.4  0. ]
#  [ 4.6  3.6  1.   0.2  0. ]
#  [ 5.1  3.3  1.7  0.5  0. ]
#  [ 4.8  3.4  1.9  0.2  0. ]
#  [ 5.   3.   1.6  0.2  0. ]
#  [ 5.   3.4  1.6  0.4  0. ]
#  [ 5.2  3.5  1.5  0.2  0. ]
#  [ 5.2  3.4  1.4  0.2  0. ]
#  [ 4.7  3.2  1.6  0.2  0. ]
#  [ 4.8  3.1  1.6  0.2  0. ]
#  [ 5.4  3.4  1.5  0.4  0. ]
#  [ 5.2  4.1  1.5  0.1  0. ]
# ...

# %%
import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

#For better understanding how our dataset 

iris = datasets.load_iris()

X = iris.data
y = iris.target
target_names = iris.target_names

pca = PCA(n_components=2)
X_r = pca.fit(X).transform(X)

lda = LinearDiscriminantAnalysis(n_components=2)
X_r2 = lda.fit(X, y).transform(X)


plt.figure()
colors = ['blue', 'red', 'green']
lw = 2

for color, i, target_name in zip(colors, [0, 1, 2], target_names):
    plt.scatter(X_r[y == i, 0], X_r[y == i, 1], color=color, alpha=.8, lw=lw,
                label=target_name)
plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.title('IRIS dataset (OX - sepal lenth, OY - sepal width)')
plt.show()

# %%
from sklearn import datasets
import pandas as pd
import numpy as np
from ipywidgets import interact_manual
@interact_manual
#getting input for further detecting type 
def get_input(length='5', width ='3', petallength = '1.5', petalwidth = '0.1'):
#если посмотреть, то наиболее важным показателем в датасете является толщина тычинки, потому что данное
# значение варируется от 0.1 до 0.6 у setosa(0), от 1.2 до 1.8 у versicolor(1)
# и от 1.6 до 2.5 у virginica(2)
    defined = 0
    if float(petalwidth) < 1:
        #при прочих других аспектах, если меньше 1 - это однозначно setosa
        print('0 - setosa')
        defined = 1
    elif float(petalwidth) >=1 and float(petalwidth) <=1.6:
        print('1 - versicolor')
        defined = 1
    elif float(petalwidth) >=1.8:
        print('2 - virginica')
        defined = 1
    #есть промежуток таких значений, что по толщине тычинки нельзя определить это 1 или 2
    #значит нужно рассмотреть другие параметры
    # максимальное значение высоты у типа 1 - 5.8
    #минимальное значение высоты у типа 2 - 5.7
    
    #максимальное значение ширины у типа 1 - 3
    #минимальное значение ширины у типа 2 - 2.5
    
    #максимальное значение ширины у типа 1 - 5.1
    #минимальное значение ширины у типа 2 - 4.5
    if defined == 0:
        if float(length) >= 5.7 and float(width) >= 2.5 and petallength >= 4.5 and petalwidth >= 1.6:
            print('2 - virginica')
        else: 
            print('1 - versicolor')
# Out:
# A Jupyter Widget
